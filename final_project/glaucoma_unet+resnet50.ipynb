# data_0492.npz
# data_0493.npz
# data_0494.npz
# data_0495.npz
# data_0496.npz
# data_0497.npz
# data_0498.npz
# data_0499.npz
# data_0500.npz
# data_0501.npz
# data_0502.npz
# data_0503.npz
# data_0504.npz
# data_0505.npz
# data_0506.npz
# data_0507.npz
# data_0508.npz
# data_0509.npz
# data_0510.npz
# data_0511.npz
# data_0512.npz
# data_0513.npz
# data_0514.npz
# data_0515.npz
# data_0516.npz
# data_0517.npz
# data_0518.npz
# data_0519.npz
# data_0520.npz
# data_0521.npz
# data_0522.npz
# data_0523.npz
# data_0524.npz
# data_0525.npz
# data_0526.npz
# data_0527.npz
# data_0528.npz
# data_0529.npz
# data_0530.npz
# data_0531.npz
# data_0532.npz
# data_0533.npz
# data_0534.npz
# data_0535.npz
# data_0536.npz
# data_0537.npz
# data_0538.npz
# data_0539.npz
# data_0540.npz
# data_0541.npz
# data_0542.npz
# data_0543.npz
# data_0544.npz
# data_0545.npz
# data_0546.npz
# data_0547.npz
# data_0548.npz
# data_0549.npz
# data_0550.npz
# data_0551.npz
# data_0552.npz
# data_0553.npz
# data_0554.npz
# data_0555.npz
# data_0556.npz
# data_0557.npz
# data_0558.npz
# data_0559.npz
# data_0560.npz
# data_0561.npz
# data_0562.npz
# data_0563.npz
# data_0564.npz
# data_0565.npz
# data_0566.npz
# data_0567.npz
# data_0568.npz
# data_0569.npz
# data_0570.npz
# data_0571.npz
# data_0572.npz
# data_0573.npz
# data_0574.npz
# data_0575.npz
# data_0576.npz
# data_0577.npz
# data_0578.npz
# data_0579.npz
# data_0580.npz
# data_0581.npz
# data_0582.npz
# data_0583.npz
# data_0584.npz
# data_0585.npz
# data_0586.npz
# data_0587.npz
# data_0588.npz
# data_0589.npz
# data_0590.npz
# data_0591.npz
# data_0592.npz
# data_0593.npz
# data_0594.npz
# data_0595.npz
# data_0596.npz
# data_0597.npz
# data_0598.npz
# data_0599.npz
# data_0600.npz
# 120000 120000

# %%
import tensorflow.keras as keras

class U_RESNET50:
    def __init__(self, inp_shape=(200, 300, 1)):
        # parameters that were reused on every convolution
        C2D_params = {
            'kernel_size': (3, 3),
            'activation': 'relu',
            'kernel_initializer': 'he_normal',
            'padding': 'same'
        }

        trans_params = {
            'kernel_size': (2, 2),
            'strides': (2, 2),
            'padding': 'same'
        }

        # initialization
        inputs = tf.keras.layers.Input(inp_shape)

        # encoder
        c1 = Conv2D(16, **C2D_params)(inputs)
        c1 = Dropout(0.1)(c1)
        c1 = Conv2D(16, **C2D_params)(c1)
        p1 = MaxPooling2D((2, 2))(c1)

        c2 = Conv2D(32, **C2D_params)(p1)
        c2 = Dropout(0.1)(c2)
        c2 = Conv2D(32, **C2D_params)(c2)
        p2 = MaxPooling2D((2, 2))(c2)

        c3 = Conv2D(64, **C2D_params)(p2)
        c3 = Dropout(0.2)(c3)
        c3 = Conv2D(64, **C2D_params)(c3)
        p3 = MaxPooling2D((2, 2))(c3)

        c4 = Conv2D(128, **C2D_params)(p3)
        c4 = Dropout(0.2)(c4)
        c4 = Conv2D(128, **C2D_params)(c4)
        p4 = MaxPooling2D((2, 2))(c4)

        # valley
        c5 = Conv2D(256, **C2D_params)(p4)
        c5 = Dropout(0.3)(c5)
        c5 = Conv2D(256, **C2D_params)(c5)

        c4_crop = keras.layers.Cropping2D(cropping=((1,0), (1,0)))(c4)

        # decoder
        u6 = Conv2DTranspose(128, **trans_params)(c5)
        u6 = concat([u6, c4_crop])
        c6 = Conv2D(128, **C2D_params)(u6)
        c6 = Dropout(0.2)(c6)
        c6 = Conv2D(128, **C2D_params)(c6)

        c3_crop = keras.layers.Cropping2D(cropping=((2, 0), (3, 0)))(c3)

        u7 = Conv2DTranspose(64, **trans_params)(c6)
        u7 = concat([u7, c3_crop])
        c7 = Conv2D(64, **C2D_params)(u7)
        c7 = Dropout(0.2)(c7)
        c7 = Conv2D(64, **C2D_params)(c7)

        c2_crop = keras.layers.Cropping2D(cropping=((4, 0), (6, 0)))(c2)

        u8 = Conv2DTranspose(32, **trans_params)(c7)
        u8 = concat([u8, c2_crop])
        c8 = Conv2D(32, **C2D_params)(u8)
        c8 = Dropout(0.1)(c8)
        c8 = Conv2D(32, **C2D_params)(c8)

        c1_crop = keras.layers.Cropping2D(cropping=((8, 0), (12, 0)))(c1)

        u9 = Conv2DTranspose(16, **trans_params)(c8)
        u9 = concat([u9, c1_crop], axis=3)
        c9 = Conv2D(16, **C2D_params)(u9)
        c9 = Dropout(0.1)(c9)
        c9 = Conv2D(16, **C2D_params)(c9)

        resnet = ResNet50(weights='imagenet', include_top=False, input_shape=(192, 288, 3))
        resnet.trainable = True

        x = Conv2D(3, (1, 1), padding='same')(c9)
        resnet_output = resnet(x)

        gap = GlobalAveragePooling2D()(resnet_output)
        final = Dense(1, activation='sigmoid')(gap)

        # compile our unet
        unet = tf.keras.Model(inputs=[inputs], outputs=[final])
        unet.compile(
            optimizer='adam',
            loss='binary_crossentropy',
            metrics=
             [
                'accuracy',
                tf.keras.metrics.AUC(),
                tf.keras.metrics.Recall(),
                tf.keras.metrics.Precision()
             ]
        )

        self.model = unet

# %%
net = U_RESNET50()
net.model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 300, 1)]        0         []
#
#  conv2d (Conv2D)             (None, 200, 300, 16)         160       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 200, 300, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 200, 300, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 100, 150, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 100, 150, 32)         4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 100, 150, 32)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 100, 150, 32)         9248      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 50, 75, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 50, 75, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 50, 75, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 50, 75, 64)           36928     ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 25, 37, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 25, 37, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 25, 37, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 25, 37, 128)          147584    ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 18, 128)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 12, 18, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 12, 18, 256)          0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 12, 18, 256)          590080    ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 24, 36, 128)          131200    ['conv2d_9[0][0]']
#  anspose)
#
#  cropping2d (Cropping2D)     (None, 24, 36, 128)          0         ['conv2d_7[0][0]']
#
#  concatenate (Concatenate)   (None, 24, 36, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'cropping2d[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 24, 36, 128)          295040    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 24, 36, 128)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 24, 36, 128)          147584    ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 48, 72, 64)           32832     ['conv2d_11[0][0]']
#  Transpose)
#
#  cropping2d_1 (Cropping2D)   (None, 48, 72, 64)           0         ['conv2d_5[0][0]']
#
#  concatenate_1 (Concatenate  (None, 48, 72, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'cropping2d_1[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 48, 72, 64)           73792     ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 48, 72, 64)           0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 48, 72, 64)           36928     ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 96, 144, 32)          8224      ['conv2d_13[0][0]']
#  Transpose)
#
#  cropping2d_2 (Cropping2D)   (None, 96, 144, 32)          0         ['conv2d_3[0][0]']
#
#  concatenate_2 (Concatenate  (None, 96, 144, 64)          0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'cropping2d_2[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 96, 144, 32)          18464     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 96, 144, 32)          0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 96, 144, 32)          9248      ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 192, 288, 16)         2064      ['conv2d_15[0][0]']
#  Transpose)
#
#  cropping2d_3 (Cropping2D)   (None, 192, 288, 16)         0         ['conv2d_1[0][0]']
#
#  concatenate_3 (Concatenate  (None, 192, 288, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'cropping2d_3[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 192, 288, 16)         4624      ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 192, 288, 16)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 192, 288, 16)         2320      ['dropout_8[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 192, 288, 3)          51        ['conv2d_17[0][0]']
#
#  resnet50 (Functional)       (None, 6, 9, 2048)           2358771   ['conv2d_18[0][0]']
#                                                           2
#
#  global_average_pooling2d (  (None, 2048)                 0         ['resnet50[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                    2049      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 25530612 (97.39 MB)
# Trainable params: 25477492 (97.19 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
from sklearn.model_selection import train_test_split

filepath = "/content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-{epoch:02d}.hdf5"

cb = [
    ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=False, mode='max', save_freq='epoch')
]

X_train, X_val, y_train, y_val = train_test_split(imgs, labels, test_size=0.2, random_state=42)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (96000, 200, 300) (96000,)
# (24000, 200, 300) (24000,)

# %%
net.model.fit(X_train, y_train, batch_size=32, epochs=10, validation_data=(X_val, y_val), callbacks=[cb])
# Out:
# Epoch 1/10
# 3000/3000 [==============================] - ETA: 0s - loss: 0.5656 - accuracy: 0.7037 - auc: 0.7682 - recall: 0.5884 - precision: 0.6913
# Epoch 1: saving model to /content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-01.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 3000/3000 [==============================] - 744s 233ms/step - loss: 0.5656 - accuracy: 0.7037 - auc: 0.7682 - recall: 0.5884 - precision: 0.6913 - val_loss: 0.4919 - val_accuracy: 0.7673 - val_auc: 0.8388 - val_recall: 0.6466 - val_precision: 0.7893
# Epoch 2/10
# 3000/3000 [==============================] - ETA: 0s - loss: 0.4689 - accuracy: 0.7737 - auc: 0.8484 - recall: 0.6766 - precision: 0.7793
# Epoch 2: saving model to /content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-02.hdf5
# 3000/3000 [==============================] - 692s 231ms/step - loss: 0.4689 - accuracy: 0.7737 - auc: 0.8484 - recall: 0.6766 - precision: 0.7793 - val_loss: 0.5641 - val_accuracy: 0.7638 - val_auc: 0.8689 - val_recall: 0.5206 - val_precision: 0.9052
# Epoch 3/10
# 3000/3000 [==============================] - ETA: 0s - loss: 0.4166 - accuracy: 0.8061 - auc: 0.8843 - recall: 0.7296 - precision: 0.8103
# Epoch 3: saving model to /content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-03.hdf5
# 3000/3000 [==============================] - 692s 231ms/step - loss: 0.4166 - accuracy: 0.8061 - auc: 0.8843 - recall: 0.7296 - precision: 0.8103 - val_loss: 0.3650 - val_accuracy: 0.8337 - val_auc: 0.9132 - val_recall: 0.7658 - val_precision: 0.8439
# Epoch 4/10
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3590 - accuracy: 0.8394 - auc: 0.9157 - recall: 0.7799 - precision: 0.8429
# Epoch 4: saving model to /content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-04.hdf5
# 3000/3000 [==============================] - 692s 231ms/step - loss: 0.3590 - accuracy: 0.8394 - auc: 0.9157 - recall: 0.7799 - precision: 0.8429 - val_loss: 0.4691 - val_accuracy: 0.8044 - val_auc: 0.9296 - val_recall: 0.5880 - val_precision: 0.9512
# Epoch 5/10
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2986 - accuracy: 0.8695 - auc: 0.9429 - recall: 0.8244 - precision: 0.8716
# Epoch 5: saving model to /content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-05.hdf5
# 3000/3000 [==============================] - 693s 231ms/step - loss: 0.2986 - accuracy: 0.8695 - auc: 0.9429 - recall: 0.8244 - precision: 0.8716 - val_loss: 0.2733 - val_accuracy: 0.8823 - val_auc: 0.9541 - val_recall: 0.8260 - val_precision: 0.8999
# Epoch 6/10
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.8995 - auc: 0.9642 - recall: 0.8676 - precision: 0.9000
# Epoch 6: saving model to /content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-06.hdf5
# 3000/3000 [==============================] - 692s 231ms/step - loss: 0.2379 - accuracy: 0.8995 - auc: 0.9642 - recall: 0.8676 - precision: 0.9000 - val_loss: 0.6122 - val_accuracy: 0.6222 - val_auc: 0.9266 - val_recall: 0.1462 - val_precision: 0.9987
# Epoch 7/10
# 3000/3000 [==============================] - ETA: 0s - loss: 0.5345 - accuracy: 0.6705 - auc: 0.7399 - recall: 0.3855 - precision: 0.7401
# Epoch 7: saving model to /content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-07.hdf5
# 3000/3000 [==============================] - 686s 229ms/step - loss: 0.5345 - accuracy: 0.6705 - auc: 0.7399 - recall: 0.3855 - precision: 0.7401 - val_loss: 1568.1215 - val_accuracy: 0.5576 - val_auc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 8/10
# 3000/3000 [==============================] - ETA: 0s - loss: 0.6886 - accuracy: 0.5548 - auc: 0.5000 - recall: 0.0446 - precision: 0.4356
# Epoch 8: saving model to /content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-08.hdf5
# 3000/3000 [==============================] - 683s 228ms/step - loss: 0.6886 - accuracy: 0.5548 - auc: 0.5000 - recall: 0.0446 - precision: 0.4356 - val_loss: 1936.6003 - val_accuracy: 0.5576 - val_auc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 9/10
# 3000/3000 [==============================] - ETA: 0s - loss: 0.6878 - accuracy: 0.5560 - auc: 0.5036 - recall: 0.0456 - precision: 0.4485
# Epoch 9: saving model to /content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-09.hdf5
# 3000/3000 [==============================] - 684s 228ms/step - loss: 0.6878 - accuracy: 0.5560 - auc: 0.5036 - recall: 0.0456 - precision: 0.4485 - val_loss: 832.2582 - val_accuracy: 0.5576 - val_auc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 10/10
# 3000/3000 [==============================] - ETA: 0s - loss: 0.6875 - accuracy: 0.5575 - auc: 0.5041 - recall: 0.0342 - precision: 0.4529
# Epoch 10: saving model to /content/drive/MyDrive/OCT/models/u_resnet/glauc-epoch-10.hdf5
# 3000/3000 [==============================] - 684s 228ms/step - loss: 0.6875 - accuracy: 0.5575 - auc: 0.5041 - recall: 0.0342 - precision: 0.4529 - val_loss: 1861.9407 - val_accuracy: 0.5576 - val_auc: 0.5000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00

# %%
net.model.history.history
keys = list(net.model.history.history.keys())
keys
# Out:
# ['loss',
#  'accuracy',
#  'auc',
#  'recall',
#  'precision',
#  'val_loss',
#  'val_accuracy',
#  'val_auc',
#  'val_recall',
#  'val_precision']

# %%
train_loss = net.model.history.history[keys[0]]
print(keys[0])

val_loss = net.model.history.history[keys[5]]
print(keys[5])

train_accuracy = net.model.history.history[keys[1]]
print(keys[1])

val_accuracy = net.model.history.history[keys[6]]
print(keys[6])

train_auc = net.model.history.history[keys[2]]
print(keys[2])

val_auc = net.model.history.history[keys[7]]
print(keys[7])

train_precision = net.model.history.history[keys[3]]
print(keys[3])

val_precision = net.model.history.history[keys[8]]
print(keys[8])

train_recall = net.model.history.history[keys[4]]
print(keys[4])

val_recall = net.model.history.history[keys[9]]
print(keys[9])

epochs = range(1, len(train_loss) + 1)
# Out:
# loss
# val_loss
# accuracy
# val_accuracy
# auc
# val_auc
# recall
# val_recall
# precision
# val_precision

# %%
plt.plot(epochs, train_accuracy, label='Train')
plt.plot(epochs, val_accuracy, label='Validation')
plt.title('Accuracy over time')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
# plt.savefig('/content/drive/MyDrive/nuclei/plots/accuracy.png')
plt.ylim(0.5, 1)
plt.show()
