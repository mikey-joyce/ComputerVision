# data_0490.npz
# data_0491.npz
# data_0492.npz
# data_0493.npz
# data_0494.npz
# data_0495.npz
# data_0496.npz
# data_0497.npz
# data_0498.npz
# data_0499.npz
# data_0500.npz
# data_0501.npz
# data_0502.npz
# data_0503.npz
# data_0504.npz
# data_0505.npz
# data_0506.npz
# data_0507.npz
# data_0508.npz
# data_0509.npz
# data_0510.npz
# data_0511.npz
# data_0512.npz
# data_0513.npz
# data_0514.npz
# data_0515.npz
# data_0516.npz
# data_0517.npz
# data_0518.npz
# data_0519.npz
# data_0520.npz
# data_0521.npz
# data_0522.npz
# data_0523.npz
# data_0524.npz
# data_0525.npz
# data_0526.npz
# data_0527.npz
# data_0528.npz
# data_0529.npz
# data_0530.npz
# data_0531.npz
# data_0532.npz
# data_0533.npz
# data_0534.npz
# data_0535.npz
# data_0536.npz
# data_0537.npz
# data_0538.npz
# data_0539.npz
# data_0540.npz
# data_0541.npz
# data_0542.npz
# data_0543.npz
# data_0544.npz
# data_0545.npz
# data_0546.npz
# data_0547.npz
# data_0548.npz
# data_0549.npz
# data_0550.npz
# data_0551.npz
# data_0552.npz
# data_0553.npz
# data_0554.npz
# data_0555.npz
# data_0556.npz
# data_0557.npz
# data_0558.npz
# data_0559.npz
# data_0560.npz
# data_0561.npz
# data_0562.npz
# data_0563.npz
# data_0564.npz
# data_0565.npz
# data_0566.npz
# data_0567.npz
# data_0568.npz
# data_0569.npz
# data_0570.npz
# data_0571.npz
# data_0572.npz
# data_0573.npz
# data_0574.npz
# data_0575.npz
# data_0576.npz
# data_0577.npz
# data_0578.npz
# data_0579.npz
# data_0580.npz
# data_0581.npz
# data_0582.npz
# data_0583.npz
# data_0584.npz
# data_0585.npz
# data_0586.npz
# data_0587.npz
# data_0588.npz
# data_0589.npz
# data_0590.npz
# data_0591.npz
# data_0592.npz
# data_0593.npz
# data_0594.npz
# data_0595.npz
# data_0596.npz
# data_0597.npz
# data_0598.npz
# data_0599.npz
# data_0600.npz
# 120000 120000

# %%
import tensorflow.keras as keras

class UNET:
    def __init__(self, inp_shape=(200, 300, 1)):
        # parameters that were reused on every convolution
        C2D_params = {
            'kernel_size': (3, 3),
            'activation': 'relu',
            'kernel_initializer': 'he_normal',
            'padding': 'same'
        }

        trans_params = {
            'kernel_size': (2, 2),
            'strides': (2, 2),
            'padding': 'same'
        }

        # initialization
        inputs = tf.keras.layers.Input(inp_shape)

        # encoder
        c1 = Conv2D(16, **C2D_params)(inputs)
        c1 = Dropout(0.1)(c1)
        c1 = Conv2D(16, **C2D_params)(c1)
        p1 = MaxPooling2D((2, 2))(c1)

        c2 = Conv2D(32, **C2D_params)(p1)
        c2 = Dropout(0.1)(c2)
        c2 = Conv2D(32, **C2D_params)(c2)
        p2 = MaxPooling2D((2, 2))(c2)

        c3 = Conv2D(64, **C2D_params)(p2)
        c3 = Dropout(0.2)(c3)
        c3 = Conv2D(64, **C2D_params)(c3)
        p3 = MaxPooling2D((2, 2))(c3)

        c4 = Conv2D(128, **C2D_params)(p3)
        c4 = Dropout(0.2)(c4)
        c4 = Conv2D(128, **C2D_params)(c4)
        p4 = MaxPooling2D((2, 2))(c4)

        # valley
        c5 = Conv2D(256, **C2D_params)(p4)
        c5 = Dropout(0.3)(c5)
        c5 = Conv2D(256, **C2D_params)(c5)

        c4_crop = keras.layers.Cropping2D(cropping=((1,0), (1,0)))(c4)

        # decoder
        u6 = Conv2DTranspose(128, **trans_params)(c5)
        u6 = concat([u6, c4_crop])
        c6 = Conv2D(128, **C2D_params)(u6)
        c6 = Dropout(0.2)(c6)
        c6 = Conv2D(128, **C2D_params)(c6)

        c3_crop = keras.layers.Cropping2D(cropping=((2, 0), (3, 0)))(c3)

        u7 = Conv2DTranspose(64, **trans_params)(c6)
        u7 = concat([u7, c3_crop])
        c7 = Conv2D(64, **C2D_params)(u7)
        c7 = Dropout(0.2)(c7)
        c7 = Conv2D(64, **C2D_params)(c7)

        c2_crop = keras.layers.Cropping2D(cropping=((4, 0), (6, 0)))(c2)

        u8 = Conv2DTranspose(32, **trans_params)(c7)
        u8 = concat([u8, c2_crop])
        c8 = Conv2D(32, **C2D_params)(u8)
        c8 = Dropout(0.1)(c8)
        c8 = Conv2D(32, **C2D_params)(c8)

        c1_crop = keras.layers.Cropping2D(cropping=((8, 0), (12, 0)))(c1)

        u9 = Conv2DTranspose(16, **trans_params)(c8)
        u9 = concat([u9, c1_crop], axis=3)
        c9 = Conv2D(16, **C2D_params)(u9)
        c9 = Dropout(0.1)(c9)
        c9 = Conv2D(16, **C2D_params)(c9)

        # unet output
        gap = GlobalAveragePooling2D()(c9)
        final = Dense(1, activation='sigmoid')(gap)

        # compile our unet
        unet = tf.keras.Model(inputs=[inputs], outputs=[final])
        unet.compile(
            optimizer='adam',
            loss='binary_crossentropy',
            metrics=
             [
                'accuracy',
                tf.keras.metrics.AUC(),
                tf.keras.metrics.Recall(),
                tf.keras.metrics.Precision()
             ]
        )

        self.model = unet

# %%
unet = UNET()
unet.model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 300, 1)]        0         []
#
#  conv2d (Conv2D)             (None, 200, 300, 16)         160       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 200, 300, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 200, 300, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 100, 150, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 100, 150, 32)         4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 100, 150, 32)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 100, 150, 32)         9248      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 50, 75, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 50, 75, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 50, 75, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 50, 75, 64)           36928     ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 25, 37, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 25, 37, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 25, 37, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 25, 37, 128)          147584    ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 18, 128)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 12, 18, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 12, 18, 256)          0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 12, 18, 256)          590080    ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 24, 36, 128)          131200    ['conv2d_9[0][0]']
#  anspose)
#
#  cropping2d (Cropping2D)     (None, 24, 36, 128)          0         ['conv2d_7[0][0]']
#
#  concatenate (Concatenate)   (None, 24, 36, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'cropping2d[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 24, 36, 128)          295040    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 24, 36, 128)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 24, 36, 128)          147584    ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 48, 72, 64)           32832     ['conv2d_11[0][0]']
#  Transpose)
#
#  cropping2d_1 (Cropping2D)   (None, 48, 72, 64)           0         ['conv2d_5[0][0]']
#
#  concatenate_1 (Concatenate  (None, 48, 72, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'cropping2d_1[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 48, 72, 64)           73792     ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 48, 72, 64)           0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 48, 72, 64)           36928     ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 96, 144, 32)          8224      ['conv2d_13[0][0]']
#  Transpose)
#
#  cropping2d_2 (Cropping2D)   (None, 96, 144, 32)          0         ['conv2d_3[0][0]']
#
#  concatenate_2 (Concatenate  (None, 96, 144, 64)          0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'cropping2d_2[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 96, 144, 32)          18464     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 96, 144, 32)          0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 96, 144, 32)          9248      ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 192, 288, 16)         2064      ['conv2d_15[0][0]']
#  Transpose)
#
#  cropping2d_3 (Cropping2D)   (None, 192, 288, 16)         0         ['conv2d_1[0][0]']
#
#  concatenate_3 (Concatenate  (None, 192, 288, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'cropping2d_3[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 192, 288, 16)         4624      ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 192, 288, 16)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 192, 288, 16)         2320      ['dropout_8[0][0]']
#
#  global_average_pooling2d (  (None, 16)                   0         ['conv2d_17[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                    17        ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 1940817 (7.40 MB)
# Trainable params: 1940817 (7.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from sklearn.model_selection import train_test_split

filepath = "/content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-{epoch:02d}.hdf5"

cb = [
    ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=False, mode='max', save_freq='epoch')
]

X_train, X_val, y_train, y_val = train_test_split(imgs, labels, test_size=0.2, random_state=42)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (96000, 200, 300) (96000,)
# (24000, 200, 300) (24000,)

# %%
unet.model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_val, y_val), callbacks=[cb])
# Out:
# Epoch 1/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.6445 - accuracy: 0.6362 - auc: 0.6767 - recall: 0.4366 - precision: 0.6227
# Epoch 1: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-01.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 3000/3000 [==============================] - 483s 152ms/step - loss: 0.6445 - accuracy: 0.6362 - auc: 0.6767 - recall: 0.4366 - precision: 0.6227 - val_loss: 0.5953 - val_accuracy: 0.6937 - val_auc: 0.7882 - val_recall: 0.3629 - val_precision: 0.8678
# Epoch 2/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.5153 - accuracy: 0.7440 - auc: 0.8146 - recall: 0.6508 - precision: 0.7360
# Epoch 2: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-02.hdf5
# 3000/3000 [==============================] - 444s 148ms/step - loss: 0.5153 - accuracy: 0.7440 - auc: 0.8146 - recall: 0.6508 - precision: 0.7360 - val_loss: 0.4727 - val_accuracy: 0.7699 - val_auc: 0.8451 - val_recall: 0.6116 - val_precision: 0.8229
# Epoch 3/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.4617 - accuracy: 0.7779 - auc: 0.8534 - recall: 0.6813 - precision: 0.7848
# Epoch 3: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-03.hdf5
# 3000/3000 [==============================] - 444s 148ms/step - loss: 0.4617 - accuracy: 0.7779 - auc: 0.8534 - recall: 0.6813 - precision: 0.7848 - val_loss: 0.4448 - val_accuracy: 0.7863 - val_auc: 0.8849 - val_recall: 0.5908 - val_precision: 0.8890
# Epoch 4/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.4209 - accuracy: 0.8005 - auc: 0.8804 - recall: 0.7156 - precision: 0.8084
# Epoch 4: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-04.hdf5
# 3000/3000 [==============================] - 443s 148ms/step - loss: 0.4209 - accuracy: 0.8005 - auc: 0.8804 - recall: 0.7156 - precision: 0.8084 - val_loss: 0.4182 - val_accuracy: 0.8028 - val_auc: 0.8920 - val_recall: 0.6551 - val_precision: 0.8667
# Epoch 5/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3986 - accuracy: 0.8146 - auc: 0.8941 - recall: 0.7380 - precision: 0.8220
# Epoch 5: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-05.hdf5
# 3000/3000 [==============================] - 441s 147ms/step - loss: 0.3986 - accuracy: 0.8146 - auc: 0.8941 - recall: 0.7380 - precision: 0.8220 - val_loss: 0.3858 - val_accuracy: 0.8195 - val_auc: 0.9103 - val_recall: 0.6610 - val_precision: 0.9056
# Epoch 6/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3596 - accuracy: 0.8365 - auc: 0.9151 - recall: 0.7713 - precision: 0.8433
# Epoch 6: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-06.hdf5
# 3000/3000 [==============================] - 440s 147ms/step - loss: 0.3596 - accuracy: 0.8365 - auc: 0.9151 - recall: 0.7713 - precision: 0.8433 - val_loss: 0.3527 - val_accuracy: 0.8428 - val_auc: 0.9233 - val_recall: 0.7245 - val_precision: 0.9007
# Epoch 7/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3331 - accuracy: 0.8503 - auc: 0.9277 - recall: 0.7942 - precision: 0.8547
# Epoch 7: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-07.hdf5
# 3000/3000 [==============================] - 440s 147ms/step - loss: 0.3331 - accuracy: 0.8503 - auc: 0.9277 - recall: 0.7942 - precision: 0.8547 - val_loss: 0.3329 - val_accuracy: 0.8514 - val_auc: 0.9297 - val_recall: 0.7648 - val_precision: 0.8837
# Epoch 8/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8609 - auc: 0.9372 - recall: 0.8121 - precision: 0.8632
# Epoch 8: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-08.hdf5
# 3000/3000 [==============================] - 440s 147ms/step - loss: 0.3119 - accuracy: 0.8609 - auc: 0.9372 - recall: 0.8121 - precision: 0.8632 - val_loss: 0.3564 - val_accuracy: 0.8328 - val_auc: 0.9521 - val_recall: 0.6387 - val_precision: 0.9744
# Epoch 9/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2929 - accuracy: 0.8716 - auc: 0.9449 - recall: 0.8272 - precision: 0.8738
# Epoch 9: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-09.hdf5
# 3000/3000 [==============================] - 439s 146ms/step - loss: 0.2929 - accuracy: 0.8716 - auc: 0.9449 - recall: 0.8272 - precision: 0.8738 - val_loss: 0.2775 - val_accuracy: 0.8782 - val_auc: 0.9518 - val_recall: 0.8118 - val_precision: 0.9030
# Epoch 10/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2751 - accuracy: 0.8806 - auc: 0.9516 - recall: 0.8413 - precision: 0.8816
# Epoch 10: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-10.hdf5
# 3000/3000 [==============================] - 439s 146ms/step - loss: 0.2751 - accuracy: 0.8806 - auc: 0.9516 - recall: 0.8413 - precision: 0.8816 - val_loss: 0.2940 - val_accuracy: 0.8680 - val_auc: 0.9595 - val_recall: 0.7334 - val_precision: 0.9584
# Epoch 11/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.8858 - auc: 0.9550 - recall: 0.8485 - precision: 0.8866
# Epoch 11: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-11.hdf5
# 3000/3000 [==============================] - 439s 146ms/step - loss: 0.2655 - accuracy: 0.8858 - auc: 0.9550 - recall: 0.8485 - precision: 0.8866 - val_loss: 0.3063 - val_accuracy: 0.8659 - val_auc: 0.9543 - val_recall: 0.7354 - val_precision: 0.9501
# Epoch 12/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.8926 - auc: 0.9603 - recall: 0.8586 - precision: 0.8929
# Epoch 12: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-12.hdf5
# 3000/3000 [==============================] - 439s 146ms/step - loss: 0.2503 - accuracy: 0.8926 - auc: 0.9603 - recall: 0.8586 - precision: 0.8929 - val_loss: 0.2718 - val_accuracy: 0.8802 - val_auc: 0.9690 - val_recall: 0.7540 - val_precision: 0.9683
# Epoch 13/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.8962 - auc: 0.9621 - recall: 0.8644 - precision: 0.8957
# Epoch 13: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-13.hdf5
# 3000/3000 [==============================] - 438s 146ms/step - loss: 0.2443 - accuracy: 0.8962 - auc: 0.9621 - recall: 0.8644 - precision: 0.8957 - val_loss: 0.2390 - val_accuracy: 0.8975 - val_auc: 0.9672 - val_recall: 0.8246 - val_precision: 0.9360
# Epoch 14/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2343 - accuracy: 0.9008 - auc: 0.9652 - recall: 0.8712 - precision: 0.8997
# Epoch 14: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-14.hdf5
# 3000/3000 [==============================] - 438s 146ms/step - loss: 0.2343 - accuracy: 0.9008 - auc: 0.9652 - recall: 0.8712 - precision: 0.8997 - val_loss: 0.2551 - val_accuracy: 0.8930 - val_auc: 0.9647 - val_recall: 0.8053 - val_precision: 0.9448
# Epoch 15/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.9021 - auc: 0.9667 - recall: 0.8726 - precision: 0.9015
# Epoch 15: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-15.hdf5
# 3000/3000 [==============================] - 438s 146ms/step - loss: 0.2292 - accuracy: 0.9021 - auc: 0.9667 - recall: 0.8726 - precision: 0.9015 - val_loss: 0.2304 - val_accuracy: 0.9022 - val_auc: 0.9718 - val_recall: 0.9282 - val_precision: 0.8615
# Epoch 16/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.9071 - auc: 0.9695 - recall: 0.8800 - precision: 0.9059
# Epoch 16: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-16.hdf5
# 3000/3000 [==============================] - 438s 146ms/step - loss: 0.2195 - accuracy: 0.9071 - auc: 0.9695 - recall: 0.8800 - precision: 0.9059 - val_loss: 0.2343 - val_accuracy: 0.9000 - val_auc: 0.9696 - val_recall: 0.8272 - val_precision: 0.9396
# Epoch 17/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9100 - auc: 0.9707 - recall: 0.8832 - precision: 0.9093
# Epoch 17: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-17.hdf5
# 3000/3000 [==============================] - 435s 145ms/step - loss: 0.2153 - accuracy: 0.9100 - auc: 0.9707 - recall: 0.8832 - precision: 0.9093 - val_loss: 0.2196 - val_accuracy: 0.9065 - val_auc: 0.9717 - val_recall: 0.9184 - val_precision: 0.8763
# Epoch 18/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2121 - accuracy: 0.9113 - auc: 0.9715 - recall: 0.8866 - precision: 0.9093
# Epoch 18: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-18.hdf5
# 3000/3000 [==============================] - 435s 145ms/step - loss: 0.2121 - accuracy: 0.9113 - auc: 0.9715 - recall: 0.8866 - precision: 0.9093 - val_loss: 0.2285 - val_accuracy: 0.9039 - val_auc: 0.9739 - val_recall: 0.8152 - val_precision: 0.9618
# Epoch 19/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2097 - accuracy: 0.9121 - auc: 0.9721 - recall: 0.8876 - precision: 0.9102
# Epoch 19: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-19.hdf5
# 3000/3000 [==============================] - 435s 145ms/step - loss: 0.2097 - accuracy: 0.9121 - auc: 0.9721 - recall: 0.8876 - precision: 0.9102 - val_loss: 0.2629 - val_accuracy: 0.8909 - val_auc: 0.9617 - val_recall: 0.8180 - val_precision: 0.9268
# Epoch 20/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.9157 - auc: 0.9737 - recall: 0.8926 - precision: 0.9135
# Epoch 20: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-20.hdf5
# 3000/3000 [==============================] - 435s 145ms/step - loss: 0.2039 - accuracy: 0.9157 - auc: 0.9737 - recall: 0.8926 - precision: 0.9135 - val_loss: 0.2106 - val_accuracy: 0.9145 - val_auc: 0.9722 - val_recall: 0.8710 - val_precision: 0.9314
# Epoch 21/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9182 - auc: 0.9748 - recall: 0.8945 - precision: 0.9172
# Epoch 21: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-21.hdf5
# 3000/3000 [==============================] - 435s 145ms/step - loss: 0.1994 - accuracy: 0.9182 - auc: 0.9748 - recall: 0.8945 - precision: 0.9172 - val_loss: 0.2085 - val_accuracy: 0.9160 - val_auc: 0.9734 - val_recall: 0.9013 - val_precision: 0.9081
# Epoch 22/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9187 - auc: 0.9760 - recall: 0.8961 - precision: 0.9170
# Epoch 22: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-22.hdf5
# 3000/3000 [==============================] - 435s 145ms/step - loss: 0.1945 - accuracy: 0.9187 - auc: 0.9760 - recall: 0.8961 - precision: 0.9170 - val_loss: 0.1875 - val_accuracy: 0.9240 - val_auc: 0.9805 - val_recall: 0.8680 - val_precision: 0.9563
# Epoch 23/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1903 - accuracy: 0.9212 - auc: 0.9772 - recall: 0.8996 - precision: 0.9193
# Epoch 23: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-23.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1903 - accuracy: 0.9212 - auc: 0.9772 - recall: 0.8996 - precision: 0.9193 - val_loss: 0.2367 - val_accuracy: 0.8990 - val_auc: 0.9780 - val_recall: 0.7932 - val_precision: 0.9736
# Epoch 24/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9222 - auc: 0.9776 - recall: 0.9008 - precision: 0.9205
# Epoch 24: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-24.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1881 - accuracy: 0.9222 - auc: 0.9776 - recall: 0.9008 - precision: 0.9205 - val_loss: 0.1742 - val_accuracy: 0.9300 - val_auc: 0.9823 - val_recall: 0.8949 - val_precision: 0.9439
# Epoch 25/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.9225 - auc: 0.9779 - recall: 0.9004 - precision: 0.9213
# Epoch 25: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-25.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1870 - accuracy: 0.9225 - auc: 0.9779 - recall: 0.9004 - precision: 0.9213 - val_loss: 0.1583 - val_accuracy: 0.9367 - val_auc: 0.9857 - val_recall: 0.9122 - val_precision: 0.9430
# Epoch 26/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1835 - accuracy: 0.9244 - auc: 0.9785 - recall: 0.9037 - precision: 0.9226
# Epoch 26: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-26.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1835 - accuracy: 0.9244 - auc: 0.9785 - recall: 0.9037 - precision: 0.9226 - val_loss: 0.1857 - val_accuracy: 0.9228 - val_auc: 0.9838 - val_recall: 0.8527 - val_precision: 0.9692
# Epoch 27/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1815 - accuracy: 0.9253 - auc: 0.9791 - recall: 0.9041 - precision: 0.9242
# Epoch 27: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-27.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1815 - accuracy: 0.9253 - auc: 0.9791 - recall: 0.9041 - precision: 0.9242 - val_loss: 0.1790 - val_accuracy: 0.9271 - val_auc: 0.9836 - val_recall: 0.9515 - val_precision: 0.8911
# Epoch 28/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1794 - accuracy: 0.9263 - auc: 0.9797 - recall: 0.9071 - precision: 0.9239
# Epoch 28: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-28.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1794 - accuracy: 0.9263 - auc: 0.9797 - recall: 0.9071 - precision: 0.9239 - val_loss: 0.2086 - val_accuracy: 0.9096 - val_auc: 0.9787 - val_recall: 0.8289 - val_precision: 0.9614
# Epoch 29/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9277 - auc: 0.9799 - recall: 0.9086 - precision: 0.9256
# Epoch 29: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-29.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1778 - accuracy: 0.9277 - auc: 0.9799 - recall: 0.9086 - precision: 0.9256 - val_loss: 0.1512 - val_accuracy: 0.9404 - val_auc: 0.9875 - val_recall: 0.8984 - val_precision: 0.9645
# Epoch 30/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.9289 - auc: 0.9810 - recall: 0.9102 - precision: 0.9267
# Epoch 30: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-30.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1728 - accuracy: 0.9289 - auc: 0.9810 - recall: 0.9102 - precision: 0.9267 - val_loss: 0.1706 - val_accuracy: 0.9301 - val_auc: 0.9836 - val_recall: 0.8871 - val_precision: 0.9517
# Epoch 31/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9302 - auc: 0.9818 - recall: 0.9111 - precision: 0.9287
# Epoch 31: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-31.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1700 - accuracy: 0.9302 - auc: 0.9818 - recall: 0.9111 - precision: 0.9287 - val_loss: 0.1508 - val_accuracy: 0.9414 - val_auc: 0.9865 - val_recall: 0.9361 - val_precision: 0.9318
# Epoch 32/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9337 - auc: 0.9833 - recall: 0.9168 - precision: 0.9312
# Epoch 32: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-32.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1623 - accuracy: 0.9337 - auc: 0.9833 - recall: 0.9168 - precision: 0.9312 - val_loss: 0.1896 - val_accuracy: 0.9268 - val_auc: 0.9780 - val_recall: 0.8824 - val_precision: 0.9487
# Epoch 33/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9331 - auc: 0.9829 - recall: 0.9148 - precision: 0.9318
# Epoch 33: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-33.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1639 - accuracy: 0.9331 - auc: 0.9829 - recall: 0.9148 - precision: 0.9318 - val_loss: 0.1960 - val_accuracy: 0.9167 - val_auc: 0.9819 - val_recall: 0.9580 - val_precision: 0.8675
# Epoch 34/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9348 - auc: 0.9831 - recall: 0.9176 - precision: 0.9329
# Epoch 34: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-34.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1625 - accuracy: 0.9348 - auc: 0.9831 - recall: 0.9176 - precision: 0.9329 - val_loss: 0.1589 - val_accuracy: 0.9382 - val_auc: 0.9850 - val_recall: 0.9134 - val_precision: 0.9450
# Epoch 35/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1590 - accuracy: 0.9357 - auc: 0.9840 - recall: 0.9199 - precision: 0.9328
# Epoch 35: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-35.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1590 - accuracy: 0.9357 - auc: 0.9840 - recall: 0.9199 - precision: 0.9328 - val_loss: 0.1804 - val_accuracy: 0.9246 - val_auc: 0.9832 - val_recall: 0.8620 - val_precision: 0.9637
# Epoch 36/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9368 - auc: 0.9844 - recall: 0.9196 - precision: 0.9355
# Epoch 36: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-36.hdf5
# 3000/3000 [==============================] - 436s 145ms/step - loss: 0.1567 - accuracy: 0.9368 - auc: 0.9844 - recall: 0.9196 - precision: 0.9355 - val_loss: 0.1833 - val_accuracy: 0.9208 - val_auc: 0.9875 - val_recall: 0.8364 - val_precision: 0.9819
# Epoch 37/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.9342 - auc: 0.9834 - recall: 0.9167 - precision: 0.9324
# Epoch 37: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-37.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1616 - accuracy: 0.9342 - auc: 0.9834 - recall: 0.9167 - precision: 0.9324 - val_loss: 0.1445 - val_accuracy: 0.9470 - val_auc: 0.9881 - val_recall: 0.9297 - val_precision: 0.9495
# Epoch 38/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1589 - accuracy: 0.9360 - auc: 0.9839 - recall: 0.9202 - precision: 0.9333
# Epoch 38: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-38.hdf5
# 3000/3000 [==============================] - 437s 146ms/step - loss: 0.1589 - accuracy: 0.9360 - auc: 0.9839 - recall: 0.9202 - precision: 0.9333 - val_loss: 0.1624 - val_accuracy: 0.9342 - val_auc: 0.9857 - val_recall: 0.8837 - val_precision: 0.9647
# Epoch 39/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1547 - accuracy: 0.9364 - auc: 0.9847 - recall: 0.9202 - precision: 0.9340
# Epoch 39: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-39.hdf5
# 3000/3000 [==============================] - 436s 145ms/step - loss: 0.1547 - accuracy: 0.9364 - auc: 0.9847 - recall: 0.9202 - precision: 0.9340 - val_loss: 0.1339 - val_accuracy: 0.9475 - val_auc: 0.9895 - val_recall: 0.9406 - val_precision: 0.9407
# Epoch 40/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9389 - auc: 0.9852 - recall: 0.9230 - precision: 0.9369
# Epoch 40: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-40.hdf5
# 3000/3000 [==============================] - 434s 145ms/step - loss: 0.1517 - accuracy: 0.9389 - auc: 0.9852 - recall: 0.9230 - precision: 0.9369 - val_loss: 0.1386 - val_accuracy: 0.9462 - val_auc: 0.9887 - val_recall: 0.9192 - val_precision: 0.9575
# Epoch 41/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9410 - auc: 0.9863 - recall: 0.9255 - precision: 0.9393
# Epoch 41: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-41.hdf5
# 3000/3000 [==============================] - 434s 145ms/step - loss: 0.1463 - accuracy: 0.9410 - auc: 0.9863 - recall: 0.9255 - precision: 0.9393 - val_loss: 0.1409 - val_accuracy: 0.9457 - val_auc: 0.9887 - val_recall: 0.9459 - val_precision: 0.9323
# Epoch 42/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1533 - accuracy: 0.9389 - auc: 0.9849 - recall: 0.9223 - precision: 0.9376
# Epoch 42: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-42.hdf5
# 3000/3000 [==============================] - 434s 145ms/step - loss: 0.1533 - accuracy: 0.9389 - auc: 0.9849 - recall: 0.9223 - precision: 0.9376 - val_loss: 0.1493 - val_accuracy: 0.9407 - val_auc: 0.9859 - val_recall: 0.9190 - val_precision: 0.9455
# Epoch 43/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9414 - auc: 0.9864 - recall: 0.9269 - precision: 0.9390
# Epoch 43: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-43.hdf5
# 3000/3000 [==============================] - 434s 145ms/step - loss: 0.1457 - accuracy: 0.9414 - auc: 0.9864 - recall: 0.9269 - precision: 0.9390 - val_loss: 0.1383 - val_accuracy: 0.9446 - val_auc: 0.9889 - val_recall: 0.9147 - val_precision: 0.9582
# Epoch 44/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9449 - auc: 0.9875 - recall: 0.9310 - precision: 0.9429
# Epoch 44: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-44.hdf5
# 3000/3000 [==============================] - 433s 144ms/step - loss: 0.1395 - accuracy: 0.9449 - auc: 0.9875 - recall: 0.9310 - precision: 0.9429 - val_loss: 0.1359 - val_accuracy: 0.9486 - val_auc: 0.9889 - val_recall: 0.9310 - val_precision: 0.9518
# Epoch 45/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9443 - auc: 0.9876 - recall: 0.9301 - precision: 0.9424
# Epoch 45: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-45.hdf5
# 3000/3000 [==============================] - 434s 145ms/step - loss: 0.1388 - accuracy: 0.9443 - auc: 0.9876 - recall: 0.9301 - precision: 0.9424 - val_loss: 0.1406 - val_accuracy: 0.9469 - val_auc: 0.9897 - val_recall: 0.9068 - val_precision: 0.9712
# Epoch 46/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9440 - auc: 0.9875 - recall: 0.9308 - precision: 0.9412
# Epoch 46: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-46.hdf5
# 3000/3000 [==============================] - 434s 145ms/step - loss: 0.1397 - accuracy: 0.9440 - auc: 0.9875 - recall: 0.9308 - precision: 0.9412 - val_loss: 0.1824 - val_accuracy: 0.9241 - val_auc: 0.9887 - val_recall: 0.8403 - val_precision: 0.9862
# Epoch 47/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9459 - auc: 0.9880 - recall: 0.9321 - precision: 0.9440
# Epoch 47: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-47.hdf5
# 3000/3000 [==============================] - 434s 145ms/step - loss: 0.1364 - accuracy: 0.9459 - auc: 0.9880 - recall: 0.9321 - precision: 0.9440 - val_loss: 0.1167 - val_accuracy: 0.9566 - val_auc: 0.9925 - val_recall: 0.9460 - val_precision: 0.9555
# Epoch 48/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9469 - auc: 0.9884 - recall: 0.9331 - precision: 0.9453
# Epoch 48: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-48.hdf5
# 3000/3000 [==============================] - 433s 144ms/step - loss: 0.1344 - accuracy: 0.9469 - auc: 0.9884 - recall: 0.9331 - precision: 0.9453 - val_loss: 0.1216 - val_accuracy: 0.9547 - val_auc: 0.9916 - val_recall: 0.9515 - val_precision: 0.9464
# Epoch 49/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9451 - auc: 0.9879 - recall: 0.9310 - precision: 0.9432
# Epoch 49: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-49.hdf5
# 3000/3000 [==============================] - 433s 144ms/step - loss: 0.1378 - accuracy: 0.9451 - auc: 0.9879 - recall: 0.9310 - precision: 0.9432 - val_loss: 0.1476 - val_accuracy: 0.9421 - val_auc: 0.9867 - val_recall: 0.9160 - val_precision: 0.9513
# Epoch 50/50
# 3000/3000 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9472 - auc: 0.9886 - recall: 0.9347 - precision: 0.9445
# Epoch 50: saving model to /content/drive/MyDrive/OCT/models/u_netbase/glauc-epoch-50.hdf5
# 3000/3000 [==============================] - 434s 145ms/step - loss: 0.1324 - accuracy: 0.9472 - auc: 0.9886 - recall: 0.9347 - precision: 0.9445 - val_loss: 0.1125 - val_accuracy: 0.9572 - val_auc: 0.9924 - val_recall: 0.9504 - val_precision: 0.9528

# %%
unet.model.history.history
keys = list(unet.model.history.history.keys())
keys
# Out:
# ['loss',
#  'accuracy',
#  'auc',
#  'recall',
#  'precision',
#  'val_loss',
#  'val_accuracy',
#  'val_auc',
#  'val_recall',
#  'val_precision']

# %%
train_loss = unet.model.history.history[keys[0]]
print(keys[0])

val_loss = unet.model.history.history[keys[5]]
print(keys[5])

train_accuracy = unet.model.history.history[keys[1]]
print(keys[1])

val_accuracy = unet.model.history.history[keys[6]]
print(keys[6])

train_auc = unet.model.history.history[keys[2]]
print(keys[2])

val_auc = unet.model.history.history[keys[7]]
print(keys[7])

train_precision = unet.model.history.history[keys[3]]
print(keys[3])

val_precision = unet.model.history.history[keys[8]]
print(keys[8])

train_recall = unet.model.history.history[keys[4]]
print(keys[4])

val_recall = unet.model.history.history[keys[9]]
print(keys[9])

epochs = range(1, len(train_loss) + 1)
# Out:
# loss
# val_loss
# accuracy
# val_accuracy
# auc
# val_auc
# recall
# val_recall
# precision
# val_precision

# %%
import matplotlib.pyplot as plt

results_dir = '/content/drive/MyDrive/OCT/models/u_netbase/results/'

plt.plot(epochs, train_loss, label='Train')
plt.plot(epochs, val_loss, label='Validation')
plt.title('Loss over time')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(results_dir + 'loss.png')
plt.show()

plt.plot(epochs, train_accuracy, label='Train')
plt.plot(epochs, val_accuracy, label='Validation')
plt.title('Accuracy over time')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig(results_dir + 'accuracy.png')
plt.ylim(0, 1)
plt.show()

plt.plot(epochs, train_auc, label='Traini')
plt.plot(epochs, val_auc, label='Validation')
plt.title('AUC over time')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.savefig(results_dir + 'auc.png')
plt.ylim(0, 1)
plt.show()

plt.plot(epochs, train_precision, label='Train')
plt.plot(epochs, val_precision, label='Validation')
plt.title('Precision over time')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.savefig(results_dir + 'precision.png')
plt.ylim(0, 1)
plt.show()

plt.plot(epochs, train_recall, label='Train')
plt.plot(epochs, val_recall, label='Validation')
plt.title('Recall over time')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.savefig(results_dir + 'recall.png')
plt.ylim(0, 1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-6db73da91804> in <cell line: 11>()
#       9 plt.ylabel('Loss')
#      10 plt.legend()
# ---> 11 plt.savefig(results_dir + 'loss.png')
#      12 plt.show()
#      13
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3341                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3342
# -> 3343             self.canvas.print_figure(fname, **kwargs)
#    3344
#    3345     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     456         """
#     457         FigureCanvasAgg.draw(self)
# --> 458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687         pil_kwargs.setdefault("format", format)
#    1688         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689         image.save(fname, **pil_kwargs)
#    1690
#    1691
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2426                 fp = builtins.open(filename, "r+b")
#    2427             else:
# -> 2428                 fp = builtins.open(filename, "w+b")
#    2429
#    2430         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/OCT/models/u_netbase/results/loss.png'
